# %% [markdown]
# # 📊 Customer Churn Prediction Dashboard
#
# ## Objective
#
# This notebook develops an interactive dashboard using Streamlit.
#
# The dashboard enables business users to:
#
# - Upload customer datasets
# - Predict customer churn
# - Analyze churn probability
# - Visualize customer insights
# - Export prediction results
#
# ---
#
# ## Why Dashboards Matter
#
# Most business users cannot use Python notebooks.
#
# Interactive dashboards allow managers and analysts to access machine learning predictions through a simple web interface.
#
# ---
#
# ## Dashboard Workflow
#
# CSV Upload
#
# ↓
#
# Data Validation
#
# ↓
#
# Machine Learning Prediction
#
# ↓
#
# Business Insights
#
# ↓
#
# Download Results

# %%
import pandas as pd

import joblib

import streamlit as st

import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       1 import pandas as pd
#       2
#       3 import joblib
#       4
# ----> 5 import streamlit as st
#       6
#       7 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'streamlit'
